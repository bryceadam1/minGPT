# %%
batches = [1000, 5000, 15050]
normals = [0.124, 0.126, 0.104]
ul2s = [0.116, 0.130, 0.116]

# %%
import matplotlib.pyplot as plt

plt.title("Performance gains after using UL2 from checkpoint \n (I don't know why my long training run was the worst)")
plt.plot(batches, normals, "--o", label='Before UL2')
plt.plot(batches, ul2s, "--o", label='After UL2')
plt.xlabel("Number of batches")
plt.ylabel("Acc (Openbookqa)")
plt.savefig("figures/ul2.png")
plt.show()
